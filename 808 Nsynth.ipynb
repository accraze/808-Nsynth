# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from magenta.models.nsynth import utils
from magenta.models.nsynth.wavenet import fastgen
from IPython.display import Audio
# %matplotlib inline
# %config InlineBackend.figure_format = 'jpg'
# Out:
# /Users/t33kt33k/anaconda3/envs/py3k/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# WARNING:tensorflow:From /Users/t33kt33k/anaconda3/envs/py3k/lib/python3.6/site-packages/magenta/models/nsynth/wavenet/masked.py:116: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.

# %%
def load_encoding(fname, sample_length=None, sr=16000, ckpt='model.ckpt-200000'):
    audio = utils.load_audio(fname, sample_length=sample_length, sr=sr)
    encoding = fastgen.encode(audio, ckpt, sample_length)
    return audio, encoding

# %%
sr = 16000
fname = '808snare.wav'
sample_length = 32000
audio, encoding = load_encoding(fname, sample_length)
fastgen.synthesize(
    encoding,
    save_paths=['gen_' + fname],
    samples_per_save=sample_length)
synthesis = utils.load_audio('gen_' + fname,
                             sample_length=sample_length,
                             sr=sr)
# Out:
# INFO:tensorflow:Restoring parameters from model.ckpt-200000
# INFO:tensorflow:Restoring parameters from model.ckpt-200000
# INFO:tensorflow:Sample: 0
# INFO:tensorflow:Saving: gen_808snare.wav
# INFO:tensorflow:Sample: 100
# INFO:tensorflow:Sample: 200
# INFO:tensorflow:Sample: 300
# INFO:tensorflow:Sample: 400
# INFO:tensorflow:Sample: 500
# INFO:tensorflow:Sample: 600
# INFO:tensorflow:Sample: 700
# INFO:tensorflow:Sample: 800
# INFO:tensorflow:Sample: 900
# INFO:tensorflow:Sample: 1000
# INFO:tensorflow:Sample: 1100
# INFO:tensorflow:Sample: 1200
# INFO:tensorflow:Sample: 1300
# INFO:tensorflow:Sample: 1400
# INFO:tensorflow:Sample: 1500
# INFO:tensorflow:Sample: 1600
# INFO:tensorflow:Sample: 1700
# INFO:tensorflow:Sample: 1800
# INFO:tensorflow:Sample: 1900
# INFO:tensorflow:Sample: 2000
# INFO:tensorflow:Sample: 2100
# INFO:tensorflow:Sample: 2200
# INFO:tensorflow:Sample: 2300
# INFO:tensorflow:Sample: 2400
# INFO:tensorflow:Sample: 2500
# INFO:tensorflow:Sample: 2600
# ...

# %%
audio_gen, encoding_gen = load_encoding('gen_808snare.wav', sample_length)
# Out:
# INFO:tensorflow:Restoring parameters from model.ckpt-200000

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 7))
axs[0].plot(encoding[0]); 
axs[0].set_title('808 Snare')
axs[1].plot(encoding_gen[0]); 
axs[1].set_title('Gen 808 Snare')
# Out:
# Text(0.5,1,'Gen 808 Snare')

# %%
fname = '808closehat.wav'
audio2, encoding2 = load_encoding(fname, sample_length)
fastgen.synthesize(
    encoding2,
    save_paths=['gen_' + fname],
    samples_per_save=sample_length)
synthesis = utils.load_audio('gen_' + fname,
                             sample_length=sample_length,
                             sr=sr)
# Out:
# INFO:tensorflow:Restoring parameters from model.ckpt-200000
# INFO:tensorflow:Restoring parameters from model.ckpt-200000
# INFO:tensorflow:Sample: 0
# INFO:tensorflow:Saving: gen_808closehat.wav
# INFO:tensorflow:Sample: 100
# INFO:tensorflow:Sample: 200
# INFO:tensorflow:Sample: 300
# INFO:tensorflow:Sample: 400
# INFO:tensorflow:Sample: 500
# INFO:tensorflow:Sample: 600
# INFO:tensorflow:Sample: 700
# INFO:tensorflow:Sample: 800
# INFO:tensorflow:Sample: 900
# INFO:tensorflow:Sample: 1000
# INFO:tensorflow:Sample: 1100
# INFO:tensorflow:Sample: 1200
# INFO:tensorflow:Sample: 1300
# INFO:tensorflow:Sample: 1400
# INFO:tensorflow:Sample: 1500
# INFO:tensorflow:Sample: 1600
# INFO:tensorflow:Sample: 1700
# INFO:tensorflow:Sample: 1800
# INFO:tensorflow:Sample: 1900
# INFO:tensorflow:Sample: 2000
# INFO:tensorflow:Sample: 2100
# INFO:tensorflow:Sample: 2200
# INFO:tensorflow:Sample: 2300
# INFO:tensorflow:Sample: 2400
# INFO:tensorflow:Sample: 2500
# ...

# %%
audio2_gen, encoding2_gen = load_encoding('gen_808closehat.wav', sample_length)
# Out:
# INFO:tensorflow:Restoring parameters from model.ckpt-200000

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 7))
axs[0].plot(encoding2[0]); 
axs[0].set_title('808 closed hi-hat')
axs[1].plot(encoding2_gen[0]); 
axs[1].set_title('Gen 808 closed hi-hat')
# Out:
# Text(0.5,1,'Gen 808 closed hi-hat')

# %%
fname = '808openhat.wav'
audio3, encoding3 = load_encoding(fname, sample_length)
fastgen.synthesize(
    encoding3,
    save_paths=['gen_' + fname],
    samples_per_save=sample_length)
synthesis = utils.load_audio('gen_' + fname,
                             sample_length=sample_length,
                             sr=sr)
# Out:
# INFO:tensorflow:Restoring parameters from model.ckpt-200000
# INFO:tensorflow:Restoring parameters from model.ckpt-200000
# INFO:tensorflow:Sample: 0
# INFO:tensorflow:Saving: gen_808openhat.wav
# INFO:tensorflow:Sample: 100
# INFO:tensorflow:Sample: 200
# INFO:tensorflow:Sample: 300
# INFO:tensorflow:Sample: 400
# INFO:tensorflow:Sample: 500
# INFO:tensorflow:Sample: 600
# INFO:tensorflow:Sample: 700
# INFO:tensorflow:Sample: 800
# INFO:tensorflow:Sample: 900
# INFO:tensorflow:Sample: 1000
# INFO:tensorflow:Sample: 1100
# INFO:tensorflow:Sample: 1200
# INFO:tensorflow:Sample: 1300
# INFO:tensorflow:Sample: 1400
# INFO:tensorflow:Sample: 1500
# INFO:tensorflow:Sample: 1600
# INFO:tensorflow:Sample: 1700
# INFO:tensorflow:Sample: 1800
# INFO:tensorflow:Sample: 1900
# INFO:tensorflow:Sample: 2000
# INFO:tensorflow:Sample: 2100
# INFO:tensorflow:Sample: 2200
# INFO:tensorflow:Sample: 2300
# INFO:tensorflow:Sample: 2400
# INFO:tensorflow:Sample: 2500
# INFO:tensorflow:Sample: 2600
# ...

# %%
audio3_gen, encoding3_gen = load_encoding('gen_808openhat.wav', sample_length)
# Out:
# INFO:tensorflow:Restoring parameters from model.ckpt-200000

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 7))
axs[0].plot(encoding3[0]); 
axs[0].set_title('808 open hi-hat')
axs[1].plot(encoding3_gen[0]); 
axs[1].set_title('Gen 808 open hi-hat')
# Out:
# Text(0.5,1,'Gen 808 open hi-hat')

# %%
fname = '808clap.wav'
audio4, encoding4 = load_encoding(fname, sample_length)
fastgen.synthesize(
    encoding4,
    save_paths=['gen_' + fname],
    samples_per_save=sample_length)
synthesis = utils.load_audio('gen_' + fname,
                             sample_length=sample_length,
                             sr=sr)
# Out:
# INFO:tensorflow:Restoring parameters from model.ckpt-200000
# INFO:tensorflow:Restoring parameters from model.ckpt-200000
# INFO:tensorflow:Sample: 0
# INFO:tensorflow:Saving: gen_808clap.wav
# INFO:tensorflow:Sample: 100
# INFO:tensorflow:Sample: 200
# INFO:tensorflow:Sample: 300
# INFO:tensorflow:Sample: 400
# INFO:tensorflow:Sample: 500
# INFO:tensorflow:Sample: 600
# INFO:tensorflow:Sample: 700
# INFO:tensorflow:Sample: 800
# INFO:tensorflow:Sample: 900
# INFO:tensorflow:Sample: 1000
# INFO:tensorflow:Sample: 1100
# INFO:tensorflow:Sample: 1200
# INFO:tensorflow:Sample: 1300
# INFO:tensorflow:Sample: 1400
# INFO:tensorflow:Sample: 1500
# INFO:tensorflow:Sample: 1600
# INFO:tensorflow:Sample: 1700
# INFO:tensorflow:Sample: 1800
# INFO:tensorflow:Sample: 1900
# INFO:tensorflow:Sample: 2000
# INFO:tensorflow:Sample: 2100
# INFO:tensorflow:Sample: 2200
# INFO:tensorflow:Sample: 2300
# INFO:tensorflow:Sample: 2400
# INFO:tensorflow:Sample: 2500
# INFO:tensorflow:Sample: 2600
# ...

# %%
audio4_gen, encoding4_gen = load_encoding('gen_808clap.wav', sample_length)
# Out:
# INFO:tensorflow:Restoring parameters from model.ckpt-200000

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 7))
axs[0].plot(encoding4[0]); 
axs[0].set_title('808 clap')
axs[1].plot(encoding4_gen[0]); 
axs[1].set_title('Gen 808 clap')
# Out:
# Text(0.5,1,'Gen 808 clap')

# %%
fname = '808cowbell.wav'
audio5, encoding5 = load_encoding(fname, sample_length)
fastgen.synthesize(
    encoding5,
    save_paths=['gen_' + fname],
    samples_per_save=sample_length)
synthesis = utils.load_audio('gen_' + fname,
                             sample_length=sample_length,
                             sr=sr)
# Out:
# INFO:tensorflow:Restoring parameters from model.ckpt-200000
# INFO:tensorflow:Restoring parameters from model.ckpt-200000
# INFO:tensorflow:Sample: 0
# INFO:tensorflow:Saving: gen_808cowbell.wav
# INFO:tensorflow:Sample: 100
# INFO:tensorflow:Sample: 200
# INFO:tensorflow:Sample: 300
# INFO:tensorflow:Sample: 400
# INFO:tensorflow:Sample: 500
# INFO:tensorflow:Sample: 600
# INFO:tensorflow:Sample: 700
# INFO:tensorflow:Sample: 800
# INFO:tensorflow:Sample: 900
# INFO:tensorflow:Sample: 1000
# INFO:tensorflow:Sample: 1100
# INFO:tensorflow:Sample: 1200
# INFO:tensorflow:Sample: 1300
# INFO:tensorflow:Sample: 1400
# INFO:tensorflow:Sample: 1500
# INFO:tensorflow:Sample: 1600
# INFO:tensorflow:Sample: 1700
# INFO:tensorflow:Sample: 1800
# INFO:tensorflow:Sample: 1900
# INFO:tensorflow:Sample: 2000
# INFO:tensorflow:Sample: 2100
# INFO:tensorflow:Sample: 2200
# INFO:tensorflow:Sample: 2300
# INFO:tensorflow:Sample: 2400
# INFO:tensorflow:Sample: 2500
# INFO:tensorflow:Sample: 2600
# ...

# %%
audio5_gen, encoding5_gen = load_encoding('gen_808cowbell.wav', sample_length)
# Out:
# INFO:tensorflow:Restoring parameters from model.ckpt-200000

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 7))
axs[0].plot(encoding5[0]); 
axs[0].set_title('808 cowbell')
axs[1].plot(encoding5_gen[0]); 
axs[1].set_title('Gen 808 cowbell')
# Out:
# Text(0.5,1,'Gen 808 cowbell')

# %%
fname = '808kik.wav'
audio6, encoding6 = load_encoding(fname, sample_length)
# Out:
# INFO:tensorflow:Restoring parameters from model.ckpt-200000

# %%
audio6_gen, encoding6_gen = load_encoding('gen_808kik.wav', sample_length)
# Out:
# INFO:tensorflow:Restoring parameters from model.ckpt-200000

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 7))
axs[0].plot(encoding6[0]); 
axs[0].set_title('808 Kickdrum')
axs[1].plot(encoding6_gen[0]); 
axs[1].set_title('Gen 808 Kickdrum')
# Out:
# Text(0.5,1,'Gen 808 Kickdrum')
